# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
# my_birthday_in_ad = datetime.date(1995, 10, 15)
# my_birthday_in_bs = NepaliDate.to_nepali_date(my_birthday_in_ad)

import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# We are going to do time series analysis and forecasting for YTD sales.

# %%
df1 = pd.read_csv("BTC.csv",parse_dates=['Date'])
df1.head()
# ytd = df.loc[df['YTD_ACTL'] == 'YTD_ACTL']
# Out:
#         Date     Open     High      Low    Close  Adj Close  Volume   APrice
# 0 2010-07-16  0.04951  0.04951  0.04951  0.04951    0.04951       0  0.049510
# 1 2010-07-17  0.04951  0.08585  0.05941  0.08584    0.08584       5  0.067675
# 2 2010-07-18  0.08584  0.09307  0.07723  0.08080    0.08080      49  0.083320
# 3 2010-07-19  0.08080  0.08181  0.07426  0.07474    0.07474      20  0.077770
# 4 2010-07-20  0.07474  0.07921  0.06634  0.07921    0.07921      42  0.076975

# %%
df=df1.drop(columns=['Open','High','Low','Close','Adj Close','Volume'])
df.tail()
# Out:
#            Date      APrice
# 3250 2019-06-09  7832.219971
# 3251 2019-06-10  7969.159912
# 3252 2019-06-11  8045.729981
# 3253 2019-06-12  8204.855225
# 3254 2019-06-13  8464.495118

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3255 entries, 0 to 3254
# Data columns (total 2 columns):
# Date       3255 non-null datetime64[ns]
# APrice     3255 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 50.9 KB

# %%
df['Date'].min()
# Out:
# Timestamp('2010-07-16 00:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2019-06-13 00:00:00')

# %% [markdown]
# ## Data preprocessing
#
# This step includes removing columns we do not need, check missing values, aggregate sales by date and so on.

# %%
df.sort_values(by=['Date'])
# Out:
#            Date      APrice
# 0    2010-07-16     0.049510
# 1    2010-07-17     0.067675
# 2    2010-07-18     0.083320
# 3    2010-07-19     0.077770
# 4    2010-07-20     0.076975
# 5    2010-07-21     0.064855
# 6    2010-07-22     0.056560
# 7    2010-07-23     0.058580
# 8    2010-07-24     0.052520
# 9    2010-07-25     0.053250
# 10   2010-07-26     0.058000
# 11   2010-07-27     0.059450
# 12   2010-07-28     0.064400
# 13   2010-07-29     0.066300
# 14   2010-07-30     0.065275
# 15   2010-07-31     0.064475
# 16   2010-08-01     0.060550
# 17   2010-08-02     0.060000
# 18   2010-08-03     0.058500
# 19   2010-08-04     0.059000
# 20   2010-08-05     0.061650
# 21   2010-08-06     0.060650
# 22   2010-08-07     0.059950
# 23   2010-08-08     0.065950
# 24   2010-08-09     0.070500
# 25   2010-08-10     0.068500
# 26   2010-08-11     0.068500
# 27   2010-08-12     0.067250
# 28   2010-08-13     0.065750
# 29   2010-08-14     0.066145
# ...         ...          ...
# 3225 2019-05-15  8028.969971
# 3226 2019-05-16  7623.034912
# 3227 2019-05-17  7319.020020
# 3228 2019-05-18  7729.609863
# 3229 2019-05-19  8095.714844
# 3230 2019-05-20  7973.110108
# 3231 2019-05-21  7787.410157
# 3232 2019-05-22  7751.695069
# 3233 2019-05-23  7936.449951
# 3234 2019-05-24  8027.764893
# 3235 2019-05-25  8392.680176
# 3236 2019-05-26  8755.700196
# 3237 2019-05-27  8752.009766
# 3238 2019-05-28  8691.704590
# 3239 2019-05-29  8470.404785
# 3240 2019-05-30  8413.459961
# 3241 2019-05-31  8553.270020
# 3242 2019-06-01  8646.890137
# 3243 2019-06-02  8426.200195
# 3244 2019-06-03  7895.980225
# 3245 2019-06-04  7734.380127
# 3246 2019-06-05  7799.324951
# 3247 2019-06-06  7904.994873
# 3248 2019-06-07  7968.204834
# 3249 2019-06-08  7788.609863
# 3250 2019-06-09  7832.219971
# 3251 2019-06-10  7969.159912
# 3252 2019-06-11  8045.729981
# 3253 2019-06-12  8204.855225
# 3254 2019-06-13  8464.495118
#
# [3255 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Date       0
# APrice     0
# dtype: int64

# %%
df = df.groupby('Date')['APrice '].sum().reset_index()

# %%
df.head()
# Out:
#         Date   APrice
# 0 2010-07-16  0.049510
# 1 2010-07-17  0.067675
# 2 2010-07-18  0.083320
# 3 2010-07-19  0.077770
# 4 2010-07-20  0.076975

# %% [markdown]
# ## Indexing with time series data

# %%
df1 = df.set_index('Date')
df1.index
# Out:
# DatetimeIndex(['2010-07-16', '2010-07-17', '2010-07-18', '2010-07-19',
#                '2010-07-20', '2010-07-21', '2010-07-22', '2010-07-23',
#                '2010-07-24', '2010-07-25',
#                ...
#                '2019-06-04', '2019-06-05', '2019-06-06', '2019-06-07',
#                '2019-06-08', '2019-06-09', '2019-06-10', '2019-06-11',
#                '2019-06-12', '2019-06-13'],
#               dtype='datetime64[ns]', name='Date', length=3246, freq=None)

# %%
 y = df1.resample('D').mean()

# %%
y['2019':]
# Out:
#                 APrice
# Date
# 2019-01-01  3813.769898
# 2019-01-02  3920.579956
# 2019-01-03  3898.435059
# 2019-01-04  3854.960083
# 2019-01-05  3864.724976
# 2019-01-06  3979.119996
# 2019-01-07  4076.625000
# 2019-01-08  4045.574951
# 2019-01-09  4044.545044
# 2019-01-10  3858.244995
# 2019-01-11  3668.674927
# 2019-01-12  3666.789917
# 2019-01-13  3607.809937
# 2019-01-14  3627.569946
# 2019-01-15  3662.569946
# 2019-01-16  3632.614990
# 2019-01-17  3664.645020
# 2019-01-18  3666.675049
# 2019-01-19  3688.915039
# 2019-01-20  3648.755005
# 2019-01-21  3569.824951
# 2019-01-22  3586.979981
# 2019-01-23  3587.045044
# 2019-01-24  3585.285035
# 2019-01-25  3590.704957
# 2019-01-26  3589.694947
# 2019-01-27  3580.790039
# 2019-01-28  3509.250000
# 2019-01-29  3435.834961
# 2019-01-30  3442.729981
# ...                 ...
# 2019-05-15  8028.969971
# 2019-05-16  7623.034912
# 2019-05-17  7319.020020
# 2019-05-18  7729.609863
# 2019-05-19  8095.714844
# 2019-05-20  7973.110108
# 2019-05-21  7787.410157
# 2019-05-22  7751.695069
# 2019-05-23  7936.449951
# 2019-05-24  8027.764893
# 2019-05-25  8392.680176
# 2019-05-26  8755.700196
# 2019-05-27  8752.009766
# 2019-05-28  8691.704590
# 2019-05-29  8470.404785
# 2019-05-30  8413.459961
# 2019-05-31  8553.270020
# 2019-06-01  8646.890137
# 2019-06-02  8426.200195
# 2019-06-03  7895.980225
# 2019-06-04  7734.380127
# 2019-06-05  7799.324951
# 2019-06-06  7904.994873
# 2019-06-07  7968.204834
# 2019-06-08  7788.609863
# 2019-06-09  7832.219971
# 2019-06-10  7969.159912
# 2019-06-11  8045.729981
# 2019-06-12  8204.855225
# 2019-06-13  8464.495118
#
# [164 rows x 1 columns]

# %% [markdown]
# ## Visualizing  sales time series

# %%
y.plot(figsize=(20, 10))
plt.show()

# %%
y = y['APrice ']
y.head()
# Out:
# Date
# 2010-07-16    0.049510
# 2010-07-17    0.067675
# 2010-07-18    0.083320
# 2010-07-19    0.077770
# 2010-07-20    0.076975
# Freq: D, Name: APrice , dtype: float64

# %%
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller, kpss
def test_stationarity(y):
    
    #Determing rolling statistics
    rolmean = y.rolling(12).mean()
    rolstd = y.rolling(12).mean()

    #Plot rolling statistics:
    orig = plt.plot(y, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    

    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(y, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(y.dropna())
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -1.385058
# p-value                           0.589418
# #Lags Used                       29.000000
# Number of Observations Used    3216.000000
# Critical Value (1%)              -3.432385
# Critical Value (5%)              -2.862439
# Critical Value (10%)             -2.567249
# dtype: float64

# %%
ts_log = np.log(y)
plt.plot(ts_log)

# %%
moving_avg = ts_log.rolling(12).mean()
plt.plot(ts_log)
plt.plot(moving_avg, color='red')

# %%
ts_log_moving_avg_diff = ts_log - moving_avg
ts_log_moving_avg_diff.head(30)
# Out:
# Date
# 2010-07-16         NaN
# 2010-07-17         NaN
# 2010-07-18         NaN
# 2010-07-19         NaN
# 2010-07-20         NaN
# 2010-07-21         NaN
# 2010-07-22         NaN
# 2010-07-23         NaN
# 2010-07-24         NaN
# 2010-07-25         NaN
# 2010-07-26         NaN
# 2010-07-27   -0.047901
# 2010-07-28    0.010166
# 2010-07-29    0.040953
# 2010-07-30    0.045712
# 2010-07-31    0.049003
# 2010-08-01    0.006196
# 2010-08-02    0.003555
# 2010-08-03   -0.024573
# 2010-08-04   -0.016657
# 2010-08-05    0.013922
# 2010-08-06   -0.013275
# 2010-08-07   -0.027640
# 2010-08-08    0.059099
# 2010-08-09    0.118274
# 2010-08-10    0.086774
# 2010-08-11    0.082756
# 2010-08-12    0.060827
# 2010-08-13    0.031404
# 2010-08-14    0.029268
# Freq: D, Name: APrice , dtype: float64

# %%
ts_log_moving_avg_diff.dropna(inplace=True)
ts_log_moving_avg_diff.head()
# Out:
# Date
# 2010-07-27   -0.047901
# 2010-07-28    0.010166
# 2010-07-29    0.040953
# 2010-07-30    0.045712
# 2010-07-31    0.049003
# Name: APrice , dtype: float64

# %%
test_stationarity(ts_log_moving_avg_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.112214e+01
# p-value                        3.444817e-20
# #Lags Used                     1.100000e+01
# Number of Observations Used    3.124000e+03
# Critical Value (1%)           -3.432445e+00
# Critical Value (5%)           -2.862466e+00
# Critical Value (10%)          -2.567263e+00
# dtype: float64

# %%
expwighted_avg = ts_log.ewm( halflife=12).mean()
plt.plot(ts_log)
plt.plot(expwighted_avg, color='red')

# %%
ts_log_ewma_diff = ts_log - expwighted_avg
test_stationarity(ts_log_ewma_diff.dropna())
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.001535e+00
# p-value                        2.326866e-12
# #Lags Used                     5.000000e+00
# Number of Observations Used    3.240000e+03
# Critical Value (1%)           -3.432370e+00
# Critical Value (5%)           -2.862432e+00
# Critical Value (10%)          -2.567245e+00
# dtype: float64

# %%
#Take first difference:
ts_log_diff = ts_log - ts_log.shift()
plt.plot(ts_log_diff)

# %%
ts_log_diff.isnull().sum()
# Out:
# 19

# %%
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -23.633427
# p-value                           0.000000
# #Lags Used                        4.000000
# Number of Observations Used    3231.000000
# Critical Value (1%)              -3.432376
# Critical Value (5%)              -2.862435
# Critical Value (10%)             -2.567246
# dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log.dropna(),freq=12)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
ts_log_decompose = residual
ts_log_decompose.dropna(inplace=True)
test_stationarity(ts_log_decompose)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.634167e+01
# p-value                        2.991664e-29
# #Lags Used                     2.800000e+01
# Number of Observations Used    3.205000e+03
# Critical Value (1%)           -3.432392e+00
# Critical Value (5%)           -2.862442e+00
# Critical Value (10%)          -2.567250e+00
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams['figure.figsize'] = (15, 10)
plot_acf(ts_log_diff, lags =20)
plot_pacf(ts_log_diff, lags =20)

plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARIMA
#ACF and PACF plots:
from statsmodels.tsa.stattools import acf, pacf  

lag_acf = acf(ts_log_diff, nlags=12)
lag_pacf = pacf(ts_log_diff, nlags=12, method='ols')

#Plot ACF:    
plt.subplot(121)    
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')

#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
#MA MODEL
model=ARIMA(ts_log.dropna(),order=(2,1,0))
results_AR=model.fit(disp=-1)
plt.plot(ts_log_diff)
plt.plot(results_AR.fittedvalues,color='red')
plt.title('RSS:%.4f'%sum((results_AR.fittedvalues-ts_log_diff)**2))
# Out:
# Text(0.5, 1.0, 'RSS:nan')

# %%
model=ARIMA(ts_log.dropna(),order=(0,1,2))
results_MA=model.fit(disp=-1)
plt.plot(ts_log_diff)
plt.plot(results_AR.fittedvalues,color='red')
plt.title('RSS:%.4f'%sum((results_AR.fittedvalues-ts_log_diff)**2))
# Out:
# Text(0.5, 1.0, 'RSS:nan')

# %%
model=ARIMA(ts_log.dropna(),order=(2,1,2))
results_ARIMA=model.fit(disp=-1)
plt.plot(ts_log_diff)
plt.plot(results_AR.fittedvalues,color='red')
plt.title('RSS:%.4f'%sum((results_AR.fittedvalues-ts_log_diff)**2))
# Out:
# Text(0.5, 1.0, 'RSS:nan')

# %%
predictions_ARIMA_diff=pd.Series(results_ARIMA.fittedvalues,copy=True)
predictions_ARIMA_diff.head()
# Out:
# Date
# 2010-07-17    0.003703
# 2010-07-18   -0.023161
# 2010-07-19   -0.037960
# 2010-07-20   -0.006213
# 2010-07-21    0.024028
# dtype: float64

# %%
predictions_ARIMA_diff_cumsum=predictions_ARIMA_diff.cumsum()
predictions_ARIMA_diff_cumsum.head()
# Out:
# Date
# 2010-07-17    0.003703
# 2010-07-18   -0.019458
# 2010-07-19   -0.057418
# 2010-07-20   -0.063631
# 2010-07-21   -0.039603
# dtype: float64

# %%
predictions_ARIMA_log=pd.Series(ts_log.ix[0],index=ts_log.index)
predictions_ARIMA_log=predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
predictions_ARIMA_log.head()
# Out:
# Date
# 2010-07-16   -3.005581
# 2010-07-17   -3.001877
# 2010-07-18   -3.025039
# 2010-07-19   -3.062999
# 2010-07-20   -3.069211
# dtype: float64

# %%
predictions_ARIMA=np.exp(predictions_ARIMA_log)
plt.plot(y)
plt.plot(predictions_ARIMA)
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-y)**2)/len(y)))
plt.savefig("ytd.png")
